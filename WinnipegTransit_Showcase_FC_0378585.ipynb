# %% [markdown]
# # **Winnipeg Transit Asignment**
# # **Data Cleaning, bulletin 123908**
# # **Felix Cazarez**

# %% [markdown]
# # **a) Please provide your observations and notes on the raw data, data model, metadata, etc.**
# ## * i. Clean up the data; spaces, typos, remove duplicates wherever possible.
# ## * Make the file ready to be used load from one IT system to another (manual interface).

# %%
import pandas as pd

#  Loading the Main file


git_url_main = 'https://raw.githubusercontent.com/Fcazarez/WNPG_Transit_Ass/main/Main.csv?token=GHSAT0AAAAAACKMXNC325HX5ER7HBPB5PXQZKYANNA'
git_url_reference = 'https://raw.githubusercontent.com/Fcazarez/WNPG_Transit_Ass/main/Reference%20Sheet.csv?token=GHSAT0AAAAAACKMXNC3VPLCTYBFD2YEWXSIZKYB6QA'
df_main = pd.read_csv(git_url_main)
df_ref = pd.read_csv(git_url_reference)
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49999 entries, 0 to 49998
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0    Request Time(a)                     49999 non-null  object
#  1    Internal Customer ID(a)             49999 non-null  int64
#  2    Internal Driver ID(a)               49999 non-null  int64
#  3    Vehicle(a)                          49999 non-null  object
#  4    Origin Address(a)                   49999 non-null  object
#  5    Origin Address(a).1                 0 non-null      float64
#  6    Origin Xcoordinate(a)               0 non-null      float64
#  7    Origin Ycoordinate(a)               0 non-null      float64
#  8    Destination Address(a)              49999 non-null  object
#  9    Destination Xcoordinate(a)          0 non-null      float64
#  10   Destination Ycoordinate(a)          0 non-null      float64
#  11   Origin City(a)                      49999 non-null  object
#  12   Timing Preference(a)                49999 non-null  object
#  13   Start Time(a)                       49999 non-null  object
#  14   End Time(a)                         49999 non-null  object
#  15   Run End Time(a)                     49999 non-null  object
#  16   Mobility Requirement Type(a)        49999 non-null  object
#  17   Guest Count(a)                      49999 non-null  object
#  18   Guest Mobility Requirement Type(a)  49999 non-null  object
#  19   Child(a)                            49999 non-null  object
#  20   Customer Age(a)                     49999 non-null  object
#  21   Trip Service Needs(a)               49999 non-null  object
#  22                                       49999 non-null  object
#  23  Unnamed: 23                          61 non-null     object
#  24  Unnamed: 24                          41 non-null     object
# dtypes: float64(5), int64(2), object(18)
# memory usage: 9.5+ MB
# <ipython-input-85-604de4712654>:9: DtypeWarning: Columns (1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ref = pd.read_csv(git_url_reference)

# %% [markdown]
# **Comments:**
#
# The dataset concerns ride requirements for Winnipeg Transit Plus.
#
# *Data Structure:* It is a 4999x24 matrix. Five rows lack information, and three rows may contain noise or irrelevant data.
#
# *Column Names:* Column names have an unnecessary (a) suffix, which could be omitted for clarity.
#
# *Data Integrity:* "Origin Address" is repeated, suggesting a data consistency issue.
#
# *Categorical Data:* Columns like "Vehicle(a)," "Origin City(a)," "Timing Preference(a)," etc., appear to contain categorical data but are detected like object which could mean some consistency issue.
#
# *Data Types:* Numerical features are currently classified as 'object' types, indicating a need for proper conversion for accurate analysis.
#
# *General Remarks:* The dataset holds valuable information, but cleaning and preprocessing steps are necessary. Addressing noise, handling data type inconsistencies, and clarifying column significance will enhance analysis accuracy.

# %%
df_main.sample(n=5, random_state=42)
# Out:
#             Request Time(a)   Internal Customer ID(a)   Internal Driver ID(a)  \
# 33552   2023-02-06T14:15:00                      4668                    2202
# 9427    2023-01-12T10:30:00                     18663                    2399
# 199     2023-01-01T12:15:00                      9219                    1742
# 12447   2023-01-15T10:21:00                     17037                    1412
# 39488   2023-02-11T12:45:00                      2710                    2852
#
#        Vehicle(a)   Origin Address(a)   Origin Address(a).1  \
# 33552     705 BUS   1225 St Mary's Rd                   NaN
# 9427      204 CAR       409 Tache Ave                   NaN
# 199      1504 BUS        25 Centre St                   NaN
# 12447    1761 CAR        21 Roslyn Rd                   NaN
# 39488    1764 CAR       409 Tache Ave                   NaN
#
#         Origin Xcoordinate(a)   Origin Ycoordinate(a)  Destination Address(a)  \
# 33552                     NaN                     NaN           21 Clayton Dr
# 9427                      NaN                     NaN            440 River Rd
# 199                       NaN                     NaN           433 River Ave
# 12447                     NaN                     NaN           300 Hugo St N
# 39488                     NaN                     NaN     107 Henry Dormer Dr
#
#         Destination Xcoordinate(a)  ...       Run End Time(a)  \
# 33552                          NaN  ...   2023-02-06T22:00:00
# 9427                           NaN  ...   2023-01-12T18:00:00
# 199                            NaN  ...   2023-01-01T20:00:00
# 12447                          NaN  ...   2023-01-15T20:00:00
# 39488                          NaN  ...   2023-02-11T19:00:00
#
#        Mobility Requirement Type(a)  Guest Count(a)  \
# 33552                        Walker               0
# 9427                       Ambulant               0
# 199              Extra Space Walker               0
# 12447                        Walker               0
# 39488                      Ambulant               0
#
#        Guest Mobility Requirement Type(a)  Child(a)  Customer Age(a)  \
# 33552                            Ambulant         0               75
# 9427                             Ambulant         0               42
# 199                              Ambulant         0               78
# 12447                            Ambulant         0               79
# 39488                            Ambulant         0               71
#
#        Trip Service Needs(a)    Unnamed: 23 Unnamed: 24
# 33552                 Walker            NaN         NaN
# 9427                                    NaN         NaN
# 199       Extra Space Walker            NaN         NaN
# 12447                 Walker            NaN         NaN
# 39488               Ambulant            NaN         NaN
#
# [5 rows x 25 columns]

# %%
rows_with_unnamed_23_data = df_main[df_main['Unnamed: 23'].notnull()]
rows_with_unnamed_23_data
# Out:
#                                 Request Time(a)   Internal Customer ID(a)  \
# 1464    Pickup With Dropoff at Appointment Time                     16552
# 1465    Pickup With Dropoff at Appointment Time                      9370
# 1466    Pickup With Dropoff at Appointment Time                     10811
# 1467                                     Pickup                     11458
# 1468                                     Pickup                     13971
# ...                                         ...                       ...
# 43962                                  Winnipeg                     10139
# 43963                                  Winnipeg                     19714
# 45869                                  Winnipeg                      5547
# 49738                                    Pickup                      5962
# 49739   Pickup With Dropoff at Appointment Time                      6476
#
#         Internal Driver ID(a)  Vehicle(a)    Origin Address(a)  \
# 1464                      609    1204 BUS         624 Broadway
# 1465                     2660    1204 BUS         624 Broadway
# 1466                     2854    1204 BUS         624 Broadway
# 1467                     2220     602 BUS     790 Sherbrook St
# 1468                     2390     602 BUS     790 Sherbrook St
# ...                       ...         ...                  ...
# 43962                     622    1204 BUS     3030 Pembina Hwy
# 43963                    2505     206 CAR                  200
# 45869                     523     722 CAR   123 Scurfield Blvd
# 49738                    1992    1502 BUS       414 Osborne St
# 49739                    1271     605 BUS         624 Broadway
#
#         Origin Address(a).1   Origin Xcoordinate(a)   Origin Ycoordinate(a)  \
# 1464                    NaN                     NaN                     NaN
# 1465                    NaN                     NaN                     NaN
# 1466                    NaN                     NaN                     NaN
# 1467                    NaN                     NaN                     NaN
# 1468                    NaN                     NaN                     NaN
# ...                     ...                     ...                     ...
# 43962                   NaN                     NaN                     NaN
# 43963                   NaN                     NaN                     NaN
# 45869                   NaN                     NaN                     NaN
# 49738                   NaN                     NaN                     NaN
# 49739                   NaN                     NaN                     NaN
#
#        Destination Address(a)   Destination Xcoordinate(a)  ...  \
# 1464                                                   NaN  ...
# 1465                                                   NaN  ...
# 1466                                                   NaN  ...
# 1467             624 Broadway                          NaN  ...
# 1468             624 Broadway                          NaN  ...
# ...                       ...                          ...  ...
# 43962                     200                          NaN  ...
# 43963             49.80920135                          NaN  ...
# 45869                     200                          NaN  ...
# 49738            624 Broadway                          NaN  ...
# 49739                       B                          NaN  ...
#
#             Run End Time(a)  Mobility Requirement Type(a)  \
# 1464    2023-01-03T10:50:00           2023-01-04T00:00:00
# 1465    2023-01-03T10:50:00           2023-01-04T00:00:00
# 1466    2023-01-03T10:50:00           2023-01-04T00:00:00
# 1467    2023-01-03T12:27:25           2023-01-03T23:00:00
# 1468    2023-01-03T12:27:25           2023-01-03T23:00:00
# ...                     ...                           ...
# 43962   2023-02-16T09:14:21           2023-02-16T09:26:16
# 43963   2023-02-16T11:11:40           2023-02-16T11:17:06
# 45869   2023-02-17T13:45:20           2023-02-17T13:52:43
# 49738   2023-02-22T12:05:00           2023-02-23T00:00:00
# 49739   2023-02-22T10:40:26           2023-02-22T23:00:00
#
#              Guest Count(a)  Guest Mobility Requirement Type(a)   Child(a)  \
# 1464     Extra Space Walker                                   0   Ambulant
# 1465     Extra Space Walker                                   0   Ambulant
# 1466     Extra Space Walker                                   0   Ambulant
# 1467     Extra Space Walker                                   0   Ambulant
# 1468     Extra Space Walker                                   0   Ambulant
# ...                     ...                                 ...        ...
# 43962   2023-02-17T00:00:00                              Walker          0
# 43963   2023-02-16T23:00:00                              Walker          0
# 45869   2023-02-17T18:30:00                            Ambulant          0
# 49738    Extra Space Walker                                   0   Ambulant
# 49739    Extra Space Walker                                   0   Ambulant
#
#        Customer Age(a)  Trip Service Needs(a)                        \
# 1464                 0                     56   Driver Instructions
# 1465                 0                     56    Extra Space Walker
# 1466                 0                     56       No Car Ambulant
# 1467                 0                     56   Driver Instructions
# 1468                 0                     56    Extra Space Walker
# ...                ...                    ...                   ...
# 43962         Ambulant                      0                    83
# 43963         Ambulant                      0                    83
# 45869         Ambulant                      0                    81
# 49738                0                     56    Extra Space Walker
# 49739                0                     56    Extra Space Walker
#
#       Unnamed: 23 Unnamed: 24
# 1464                      NaN
# 1465                      NaN
# 1466                      NaN
# 1467                      NaN
# 1468                      NaN
# ...           ...         ...
# 43962      Walker
# 43963      Walker
# 45869    Ambulant
# 49738                     NaN
# 49739                     NaN
#
# [61 rows x 25 columns]

# %% [markdown]
# **Comments:**
#
# Numerous columns contain incorrect values, with the first column featuring misplaced data. Issues persist in the mobility requirement, guest count, guest mobility, and age columns.
#
# The last three columns contain ambiguous and noisy data. Regarding the "Unnamed: 23" column, it contains noise in 0.122% of the dataset (61 rows).
#
# Given this proportion falls below the 5% threshold, removing these rows won't significantly affect the DataFrame's overall meaning

# %%
df_main.drop(rows_with_unnamed_23_data.index, inplace=True)

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49938 entries, 0 to 49998
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0    Request Time(a)                     49938 non-null  object
#  1    Internal Customer ID(a)             49938 non-null  int64
#  2    Internal Driver ID(a)               49938 non-null  int64
#  3    Vehicle(a)                          49938 non-null  object
#  4    Origin Address(a)                   49938 non-null  object
#  5    Origin Address(a).1                 0 non-null      float64
#  6    Origin Xcoordinate(a)               0 non-null      float64
#  7    Origin Ycoordinate(a)               0 non-null      float64
#  8    Destination Address(a)              49938 non-null  object
#  9    Destination Xcoordinate(a)          0 non-null      float64
#  10   Destination Ycoordinate(a)          0 non-null      float64
#  11   Origin City(a)                      49938 non-null  object
#  12   Timing Preference(a)                49938 non-null  object
#  13   Start Time(a)                       49938 non-null  object
#  14   End Time(a)                         49938 non-null  object
#  15   Run End Time(a)                     49938 non-null  object
#  16   Mobility Requirement Type(a)        49938 non-null  object
#  17   Guest Count(a)                      49938 non-null  object
#  18   Guest Mobility Requirement Type(a)  49938 non-null  object
#  19   Child(a)                            49938 non-null  object
#  20   Customer Age(a)                     49938 non-null  object
#  21   Trip Service Needs(a)               49938 non-null  object
#  22                                       49938 non-null  object
#  23  Unnamed: 23                          0 non-null      object
#  24  Unnamed: 24                          0 non-null      object
# dtypes: float64(5), int64(2), object(18)
# memory usage: 9.9+ MB

# %%
# Create a DataFrame to store unique values
unique_values_df = pd.DataFrame(columns=['Column', 'Unique_Values'])

# Iterate over columns
for column in df_main.columns:
    unique_values = df_main[column].unique()
    unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)

# Display the results
unique_values_df
# Out:
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
# <ipython-input-55-9ba719bafc99>:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_values_df = unique_values_df.append({'Column': column, 'Unique_Values': unique_values}, ignore_index=True)
#                                  Column  \
# 0                       Request Time(a)
# 1               Internal Customer ID(a)
# 2                 Internal Driver ID(a)
# 3                            Vehicle(a)
# 4                     Origin Address(a)
# 5                   Origin Address(a).1
# 6                 Origin Xcoordinate(a)
# 7                 Origin Ycoordinate(a)
# 8                Destination Address(a)
# 9            Destination Xcoordinate(a)
# 10           Destination Ycoordinate(a)
# 11                       Origin City(a)
# 12                 Timing Preference(a)
# 13                        Start Time(a)
# 14                          End Time(a)
# 15                      Run End Time(a)
# 16         Mobility Requirement Type(a)
# 17                       Guest Count(a)
# 18   Guest Mobility Requirement Type(a)
# 19                             Child(a)
# 20                      Customer Age(a)
# 21                Trip Service Needs(a)
# 22
# 23                          Unnamed: 23
# 24                          Unnamed: 24
#
#                                         Unique_Values
# 0   [ 2023-01-01T10:42:00,  2023-01-01T09:31:00,  ...
# 1   [17154, 2015, 7701, 15671, 6445, 17784, 15179,...
# 2   [2192, 2103, 2642, 2921, 1204, 2710, 888, 1732...
# 3   [ 202 CAR,  675-02 CAR,  1204 BUS,  804 BUS,  ...
# 4   [ 374 Edmonton St,  1080 Powers St,  167 Colon...
# 5                                               [nan]
# 6                                               [nan]
# 7                                               [nan]
# 8   [ 305 Machray Ave,  1350 Grant Ave,  560 Bever...
# 9                                               [nan]
# 10                                              [nan]
# 11   [ Winnipeg,  Winnippeg,  Winnnipeg,  Sandy Hook]
# 12  [ Pickup With Dropoff at Appointment Time,  Pi...
# 13  [ 2023-01-01T10:44:31,  2023-01-01T09:08:21,  ...
# 14  [ 2023-01-01T10:56:44,  2023-01-01T09:29:58,  ...
# 15  [ 2023-01-01T22:00:00,  2023-01-01T20:00:00,  ...
# 16  [ Walker,  Wheelchair,  Ambulant,  Large Wheel...
# 17                                     [0, 1, 100, 2]
# 18  [ Ambulant,  ,  Extra Space Walker,  Walker,  ...
# 19                                                [0]
# 20  [62, 54, 43, 75, 61, 55, 77, 47, 68, 52, 65, 8...
# 21  [ Walker,  Driver Instructions,  Wheelchair 1,...
# 22                                                [ ]
# 23                                              [nan]
# 24                                              [nan]

# %% [markdown]
# ### DataFrame Comment:
#
# The following features contain no values and can be safely removed from the dataset:
#
# - 'Origin Address(a).1'
# - 'Origin Xcoordinate(a)'
# - 'Origin Ycoordinate(a)'
# - 'Destination Xcoordinate(a)'
# - 'Destination Ycoordinate(a)'
# - 'Child(a)'
# - (Empty Column)
# - 'Unnamed: 23'
# - 'Unnamed: 24'
#
# These columns do not contribute meaningful information and can be dropped for a cleaner and more efficient analysis.

# %% [markdown]
# ### Comment:
#
# To identify, rename and drop columns with NaN or empty values, It is better to print the column names directly from the DataFrame. Some column names may include special characters to ensure accuracy in the removal process.

# %%
# Print the names to drop the NAN or empty columns
print(df_main.columns)
# Out:
# Index([' Request Time(a)', ' Internal Customer ID(a)',
#        ' Internal Driver ID(a)', ' Vehicle(a)', ' Origin Address(a)',
#        ' Origin Address(a).1', ' Origin Xcoordinate(a)',
#        ' Origin Ycoordinate(a)', ' Destination Address(a)',
#        ' Destination Xcoordinate(a)', ' Destination Ycoordinate(a)',
#        ' Origin City(a)', ' Timing Preference(a)', ' Start Time(a)',
#        ' End Time(a)', ' Run End Time(a)', ' Mobility Requirement Type(a)',
#        ' Guest Count(a)', ' Guest Mobility Requirement Type(a)', ' Child(a)',
#        ' Customer Age(a)', ' Trip Service Needs(a)', ' ', 'Unnamed: 23',
#        'Unnamed: 24'],
#       dtype='object')

# %%
columns_to_drop = [' Origin Address(a).1',
                   ' Origin Xcoordinate(a)',
                   ' Origin Ycoordinate(a)',
                   ' Destination Xcoordinate(a)',
                   ' Destination Ycoordinate(a)',
                   ' Child(a)', ' ', 'Unnamed: 23',
                   'Unnamed: 24']

# Check if the columns exist before attempting to drop them
missing_columns = [col for col in columns_to_drop if col not in df_main.columns]

# Drop the columns only if they exist
if not missing_columns:
    df_main.drop(columns=columns_to_drop, inplace=True)
    print("Columns dropped successfully.")
else:
    print(f"Columns not found: {missing_columns}")
# Out:
# Columns dropped successfully.

# %%
# Create a dictionary to map old column names to new names
new_column_names = {' Request Time(a)' : 'Request_Time',
                    ' Internal Customer ID(a)' : 'Internal_Customer_ID',
                    ' Internal Driver ID(a)' : 'Internal_Driver_ID',
                    ' Vehicle(a)': 'Vehicle',
                    ' Origin Address(a)': 'Origin_Address',
                    ' Destination Address(a)': 'Destination_Address',
                    ' Origin City(a)':'Origin_City',
                    ' Timing Preference(a)':'Timing_Preference',
                    ' Start Time(a)': 'Start_Time',
                    ' End Time(a)': 'End_Time',
                    ' Run End Time(a)': 'Run_End_Time',
                    ' Mobility Requirement Type(a)': 'Mobility_Requirement_Type',
                    ' Guest Count(a)': 'Guest_Count',
                    ' Guest Mobility Requirement Type(a)': 'Guest_Mobility_Requirement_Type',
                    ' Customer Age(a)': 'Customer_Age',
                    ' Trip Service Needs(a)': 'Trip_Service_Needs'
}

# Rename the columns using the dictionary
df_main.rename(columns=new_column_names, inplace=True)

# Verify the changes
df_main.head().T
# Out:
#                                                                         0  \
# Request_Time                                          2023-01-01T10:42:00
# Internal_Customer_ID                                                17154
# Internal_Driver_ID                                                   2192
# Vehicle                                                           202 CAR
# Origin_Address                                            374 Edmonton St
# Destination_Address                                       305 Machray Ave
# Origin_City                                                      Winnipeg
# Timing_Preference                 Pickup With Dropoff at Appointment Time
# Start_Time                                            2023-01-01T10:44:31
# End_Time                                              2023-01-01T10:56:44
# Run_End_Time                                          2023-01-01T22:00:00
# Mobility_Requirement_Type                                          Walker
# Guest_Count                                                             0
# Guest_Mobility_Requirement_Type                                  Ambulant
# Customer_Age                                                           62
# Trip_Service_Needs                                                 Walker
#
#                                                                         1  \
# Request_Time                                          2023-01-01T09:31:00
# Internal_Customer_ID                                                 2015
# Internal_Driver_ID                                                   2103
# Vehicle                                                        675-02 CAR
# Origin_Address                                             1080 Powers St
# Destination_Address                                        1350 Grant Ave
# Origin_City                                                      Winnipeg
# Timing_Preference                 Pickup With Dropoff at Appointment Time
# Start_Time                                            2023-01-01T09:08:21
# End_Time                                              2023-01-01T09:29:58
# Run_End_Time                                          2023-01-01T20:00:00
# Mobility_Requirement_Type                                          Walker
# Guest_Count                                                             0
# Guest_Mobility_Requirement_Type                                  Ambulant
# Customer_Age                                                           54
# Trip_Service_Needs                                                 Walker
#
#                                                     2                     3  \
# Request_Time                      2023-01-01T20:39:00   2023-01-01T20:39:00
# Internal_Customer_ID                             7701                 15671
# Internal_Driver_ID                               2642                  2921
# Vehicle                                      1204 BUS              1204 BUS
# Origin_Address                          167 Colony St         167 Colony St
# Destination_Address                   560 Beverley St       560 Beverley St
# Origin_City                                  Winnipeg              Winnipeg
# Timing_Preference                              Pickup                Pickup
# Start_Time                        2023-01-01T20:16:55   2023-01-01T20:16:55
# End_Time                          2023-01-01T20:27:55   2023-01-01T20:27:55
# Run_End_Time                      2023-01-01T22:30:00   2023-01-01T22:30:00
# Mobility_Requirement_Type                  Wheelchair            Wheelchair
# Guest_Count                                         0                     0
# Guest_Mobility_Requirement_Type              Ambulant              Ambulant
# Customer_Age                                       43                    43
# Trip_Service_Needs                Driver Instructions          Wheelchair 1
#
#                                                                         4
# Request_Time                                          2023-01-01T18:18:00
# Internal_Customer_ID                                                 6445
# Internal_Driver_ID                                                   1204
# Vehicle                                                           804 BUS
# Origin_Address                                             408 Paufeld Dr
# Destination_Address                                         167 Colony St
# Origin_City                                                      Winnipeg
# Timing_Preference                 Pickup With Dropoff at Appointment Time
# Start_Time                                            2023-01-01T18:02:30
# End_Time                                              2023-01-01T18:33:32
# Run_End_Time                                          2023-01-01T20:00:00
# Mobility_Requirement_Type                                      Wheelchair
# Guest_Count                                                             0
# Guest_Mobility_Requirement_Type                                  Ambulant
# Customer_Age                                                           43
# Trip_Service_Needs                                    Driver Instructions

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49938 entries, 0 to 49998
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Request_Time                     49938 non-null  object
#  1   Internal_Customer_ID             49938 non-null  int64
#  2   Internal_Driver_ID               49938 non-null  int64
#  3   Vehicle                          49938 non-null  object
#  4   Origin_Address                   49938 non-null  object
#  5   Destination_Address              49938 non-null  object
#  6   Origin_City                      49938 non-null  object
#  7   Timing_Preference                49938 non-null  object
#  8   Start_Time                       49938 non-null  object
#  9   End_Time                         49938 non-null  object
#  10  Run_End_Time                     49938 non-null  object
#  11  Mobility_Requirement_Type        49938 non-null  object
#  12  Guest_Count                      49938 non-null  object
#  13  Guest_Mobility_Requirement_Type  49938 non-null  object
#  14  Customer_Age                     49938 non-null  object
#  15  Trip_Service_Needs               49938 non-null  object
# dtypes: int64(2), object(14)
# memory usage: 6.5+ MB

# %%
# Check for duplicated rows
duplicated_rows = df_main[df_main.duplicated()]
print("Duplicated Rows:")
print(duplicated_rows)
# Out:
# Duplicated Rows:
# Empty DataFrame
# Columns: [Request_Time, Internal_Customer_ID, Internal_Driver_ID, Vehicle, Origin_Address, Destination_Address, Origin_City, Timing_Preference, Start_Time, End_Time, Run_End_Time, Mobility_Requirement_Type, Guest_Count, Guest_Mobility_Requirement_Type, Customer_Age, Trip_Service_Needs]
# Index: []

# %%
# Create a DataFrame with features as rows
features_df = pd.DataFrame(df_main.columns, columns=['Features'])

# Add a column for missing values
features_df['Missing_Values'] = df_main.isnull().sum().values

# Add a column for NaN values
features_df['NaN_Values'] = df_main.isna().sum().values

# Display the resulting DataFrame
features_df
# Out:
#                            Features  Missing_Values  NaN_Values
# 0                      Request_Time               0           0
# 1              Internal_Customer_ID               0           0
# 2                Internal_Driver_ID               0           0
# 3                           Vehicle               0           0
# 4                    Origin_Address               0           0
# 5               Destination_Address               0           0
# 6                       Origin_City               0           0
# 7                 Timing_Preference               0           0
# 8                        Start_Time               0           0
# 9                          End_Time               0           0
# 10                     Run_End_Time               0           0
# 11        Mobility_Requirement_Type               0           0
# 12                      Guest_Count               0           0
# 13  Guest_Mobility_Requirement_Type               0           0
# 14                     Customer_Age               0           0
# 15               Trip_Service_Needs               0           0

# %%
# Save the clean data file
from google.colab import drive
drive.mount('/content/drive')

df_main.to_csv('/content/drive/MyDrive/Colab Notebooks/WNPG_Transit/clean_data.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **b) Format data for manipulation (tables). Create separate columns and extract.**
# ## * **i. Date and time separately**
# ## * **ii. Vehicle Number and vehicle type**

# %%
# Assuming df is your DataFrame
time_columns = df_main.iloc[:, [0, 3, 8, 9, 10]]

# Display the selected columns
time_columns
# Out:
#              Request_Time      Vehicle          Start_Time  \
# 0     2023-01-01 10:42:00      202 CAR 2023-01-01 10:44:31
# 1     2023-01-01 09:31:00   675-02 CAR 2023-01-01 09:08:21
# 2     2023-01-01 20:39:00     1204 BUS 2023-01-01 20:16:55
# 3     2023-01-01 20:39:00     1204 BUS 2023-01-01 20:16:55
# 4     2023-01-01 18:18:00      804 BUS 2023-01-01 18:02:30
# ...                   ...          ...                 ...
# 49994 2023-02-22 14:44:00      201 CAR 2023-02-22 14:42:18
# 49995 2023-02-22 17:15:00      201 CAR 2023-02-22 16:45:29
# 49996 2023-02-22 14:30:00     1501 BUS 2023-02-22 14:27:40
# 49997 2023-02-22 18:45:00     1201 BUS 2023-02-22 18:38:27
# 49998 2023-02-22 07:12:00      701 BUS 2023-02-22 07:04:19
#
#                  End_Time        Run_End_Time
# 0     2023-01-01 10:56:44 2023-01-01 22:00:00
# 1     2023-01-01 09:29:58 2023-01-01 20:00:00
# 2     2023-01-01 20:27:55 2023-01-01 22:30:00
# 3     2023-01-01 20:27:55 2023-01-01 22:30:00
# 4     2023-01-01 18:33:32 2023-01-01 20:00:00
# ...                   ...                 ...
# 49994 2023-02-22 14:51:37 2023-02-23 00:00:00
# 49995 2023-02-22 16:55:40 2023-02-23 00:00:00
# 49996 2023-02-22 14:36:38 2023-02-23 00:00:00
# 49997 2023-02-22 18:51:52 2023-02-22 20:30:00
# 49998 2023-02-22 07:32:07 2023-02-22 23:00:00
#
# [49938 rows x 5 columns]

# %%
df_main.iloc[:, 3]
# Out:
# 0            202 CAR
# 1         675-02 CAR
# 2           1204 BUS
# 3           1204 BUS
# 4            804 BUS
#             ...
# 49994        201 CAR
# 49995        201 CAR
# 49996       1501 BUS
# 49997       1201 BUS
# 49998        701 BUS
# Name: Vehicle, Length: 49938, dtype: object

# %%
clean_data = df_main

# %%
df_main
# Out:
#                Request_Time  Internal_Customer_ID  Internal_Driver_ID  \
# 0       2023-01-01T10:42:00                 17154                2192
# 1       2023-01-01T09:31:00                  2015                2103
# 2       2023-01-01T20:39:00                  7701                2642
# 3       2023-01-01T20:39:00                 15671                2921
# 4       2023-01-01T18:18:00                  6445                1204
# ...                     ...                   ...                 ...
# 49994   2023-02-22T14:44:00                  2589                 596
# 49995   2023-02-22T17:15:00                  7531                 561
# 49996   2023-02-22T14:30:00                  6622                2731
# 49997   2023-02-22T18:45:00                  6248                1307
# 49998   2023-02-22T07:12:00                 10699                1457
#
#            Vehicle        Origin_Address Destination_Address Origin_City  \
# 0          202 CAR       374 Edmonton St     305 Machray Ave    Winnipeg
# 1       675-02 CAR        1080 Powers St      1350 Grant Ave    Winnipeg
# 2         1204 BUS         167 Colony St     560 Beverley St    Winnipeg
# 3         1204 BUS         167 Colony St     560 Beverley St    Winnipeg
# 4          804 BUS        408 Paufeld Dr       167 Colony St    Winnipeg
# ...            ...                   ...                 ...         ...
# 49994      201 CAR       196 Hindley Ave    166 Meadowood Dr    Winnipeg
# 49995      201 CAR      166 Meadowood Dr     196 Hindley Ave    Winnipeg
# 49996     1501 BUS         545 Peguis St   1555 Regent Ave W    Winnipeg
# 49997     1201 BUS     1555 Regent Ave W       545 Peguis St    Winnipeg
# 49998      701 BUS   63 Rick Boychuk Bay    820 Sherbrook St    Winnipeg
#
#                               Timing_Preference            Start_Time  \
# 0       Pickup With Dropoff at Appointment Time   2023-01-01T10:44:31
# 1       Pickup With Dropoff at Appointment Time   2023-01-01T09:08:21
# 2                                        Pickup   2023-01-01T20:16:55
# 3                                        Pickup   2023-01-01T20:16:55
# 4       Pickup With Dropoff at Appointment Time   2023-01-01T18:02:30
# ...                                         ...                   ...
# 49994   Pickup With Dropoff at Appointment Time   2023-02-22T14:42:18
# 49995                                    Pickup   2023-02-22T16:45:29
# 49996                                    Pickup   2023-02-22T14:27:40
# 49997                                    Pickup   2023-02-22T18:38:27
# 49998   Pickup With Dropoff at Appointment Time   2023-02-22T07:04:19
#
#                    End_Time          Run_End_Time   Mobility_Requirement_Type  \
# 0       2023-01-01T10:56:44   2023-01-01T22:00:00                      Walker
# 1       2023-01-01T09:29:58   2023-01-01T20:00:00                      Walker
# 2       2023-01-01T20:27:55   2023-01-01T22:30:00                  Wheelchair
# 3       2023-01-01T20:27:55   2023-01-01T22:30:00                  Wheelchair
# 4       2023-01-01T18:33:32   2023-01-01T20:00:00                  Wheelchair
# ...                     ...                   ...                         ...
# 49994   2023-02-22T14:51:37   2023-02-23T00:00:00                    Ambulant
# 49995   2023-02-22T16:55:40   2023-02-23T00:00:00                    Ambulant
# 49996   2023-02-22T14:36:38   2023-02-23T00:00:00   Scooter or Power Pedestal
# 49997   2023-02-22T18:51:52   2023-02-22T20:30:00   Scooter or Power Pedestal
# 49998   2023-02-22T07:32:07   2023-02-22T23:00:00                  Wheelchair
#
#       Guest_Count Guest_Mobility_Requirement_Type Customer_Age  \
# 0               0                        Ambulant           62
# 1               0                        Ambulant           54
# 2               0                        Ambulant           43
# 3               0                        Ambulant           43
# 4               0                        Ambulant           43
# ...           ...                             ...          ...
# 49994           1                        Ambulant           74
# 49995           1                        Ambulant           74
# 49996           0                        Ambulant           79
# 49997           0                        Ambulant           79
# 49998           0                        Ambulant           77
#
#                Trip_Service_Needs
# 0                          Walker
# 1                          Walker
# 2             Driver Instructions
# 3                    Wheelchair 1
# 4             Driver Instructions
# ...                           ...
# 49994                    Ambulant
# 49995                    Ambulant
# 49996   Scooter or Power Pedestal
# 49997   Scooter or Power Pedestal
# 49998                Wheelchair 1
#
# [49938 rows x 16 columns]

# %%
import pandas as pd

# Columns to be transformed
time_columns = ['Request_Time', 'Start_Time', 'End_Time', 'Run_End_Time']

for col in time_columns:
    clean_data[col] = pd.to_datetime(clean_data[col], errors='coerce')
    clean_data[f'{col}_Date'] = clean_data[col].dt.date
    clean_data[f'{col}_Time'] = clean_data[col].dt.time

# Drop the original columns
# clean_data.drop(columns=time_columns, inplace=True)

# Display the updated DataFrame
selected_columns = clean_data[['Request_Time_Date', 'Request_Time_Time', 'Start_Time_Date', 'Start_Time_Time', 'End_Time_Date', 'End_Time_Time', 'Run_End_Time_Date', 'Run_End_Time_Time']]
print(selected_columns.sample(10))
# Out:
#       Request_Time_Date Request_Time_Time Start_Time_Date Start_Time_Time  \
# 49255        2023-02-22          16:19:00      2023-02-22        16:19:53
# 43321        2023-02-15          14:30:00      2023-02-15        14:14:16
# 15491        2023-01-18          12:30:00      2023-01-18        12:10:12
# 26246        2023-01-29          19:00:00      2023-01-29        18:50:15
# 45375        2023-02-17          14:09:00      2023-02-17        14:27:50
# 17422        2023-01-20          18:15:00      2023-01-20        18:03:49
# 37298        2023-02-09          11:15:00      2023-02-09        11:36:49
# 33643        2023-02-06          11:24:00      2023-02-06        11:16:36
# 22403        2023-01-25          15:15:00      2023-01-25        15:29:37
# 27672        2023-01-31          07:45:00      2023-01-31        07:33:45
#
#       End_Time_Date End_Time_Time Run_End_Time_Date Run_End_Time_Time
# 49255    2023-02-22      16:55:40        2023-02-23          00:00:00
# 43321    2023-02-15      14:41:51        2023-02-15          18:30:00
# 15491    2023-01-18      12:30:34        2023-01-18          23:00:00
# 26246    2023-01-29      19:04:50        2023-01-29          22:30:00
# 45375    2023-02-17      15:00:30        2023-02-17          19:00:00
# 17422    2023-01-20      18:24:22        2023-01-20          23:00:00
# 37298    2023-02-09      11:58:57        2023-02-09          18:30:00
# 33643    2023-02-06      11:35:12        2023-02-06          18:30:00
# 22403    2023-01-25      15:47:18        2023-01-25          23:00:00
# 27672    2023-01-31      07:49:16        2023-01-31          10:00:00

# %%
# Step 1: Use a regular expression to extract the vehicle number and type
vehicle_info = clean_data['Vehicle'].str.extract(r'(\d+)-?\s(.*)')

# Step 2: Assign the extracted information to new columns in the DataFrame
clean_data['Vehicle_Number'] = vehicle_info[0]  # The first part (digits) goes into 'Vehicle_Number'
clean_data['Vehicle_Type'] = vehicle_info[1]  # The second part (remaining text) goes into 'Vehicle_Type'

# Display the updated DataFrame
selected_columns = clean_data[['Vehicle', 'Vehicle_Number', 'Vehicle_Type']]
print(selected_columns.sample(10))
# Out:
#          Vehicle Vehicle_Number Vehicle_Type
# 24813   1502 BUS           1502          BUS
# 13811   1761 CAR           1761          CAR
# 11604    606 BUS            606          BUS
# 26677   1206 BUS           1206          BUS
# 20204    784 CAR            784          CAR
# 26364    201 CAR            201          CAR
# 32007   1501 BUS           1501          BUS
# 27030    205 CAR            205          CAR
# 15172    201 CAR            201          CAR
# 9346    1503 BUS           1503          BUS

# %%
clean_data.sample(5)
# Out:
#              Request_Time  Internal_Customer_ID  Internal_Driver_ID  \
# 19238 2023-01-22 17:45:00                  2382                 643
# 23630 2023-01-26 18:05:00                  7646                 804
# 16407 2023-01-19 14:00:00                 12820                1698
# 41898 2023-02-14 10:15:00                 11071                2201
# 21561 2023-01-24 17:01:00                  5800                2321
#
#          Vehicle       Origin_Address  Destination_Address Origin_City  \
# 19238    602 BUS     826 Regent Ave W   31 Cloverdale Cres    Winnipeg
# 23630   1742 CAR   2300 Mcphillips St     3567 Portage Ave    Winnipeg
# 16407   1505 BUS      167 Lombard Ave     57 Red Spruce Rd    Winnipeg
# 41898    805 BUS        409 Tache Ave          23 Upton Pl    Winnipeg
# 21561   1503 BUS          360 Main St      38 Meredith Bay    Winnipeg
#
#                               Timing_Preference          Start_Time  \
# 19238                                    Pickup 2023-01-22 17:35:42
# 23630                                    Pickup 2023-01-26 18:21:02
# 16407                                    Pickup 2023-01-19 14:00:37
# 41898                                    Pickup 2023-02-14 10:14:01
# 21561   Pickup With Dropoff at Appointment Time 2023-01-24 17:06:11
#
#                  End_Time  ... Request_Time_Date Request_Time_Time  \
# 19238 2023-01-22 17:41:54  ...        2023-01-22          17:45:00
# 23630 2023-01-26 18:53:14  ...        2023-01-26          18:05:00
# 16407 2023-01-19 14:35:14  ...        2023-01-19          14:00:00
# 41898 2023-02-14 10:34:12  ...        2023-02-14          10:15:00
# 21561 2023-01-24 17:47:32  ...        2023-01-24          17:01:00
#
#       Start_Time_Date Start_Time_Time End_Time_Date End_Time_Time  \
# 19238      2023-01-22        17:35:42    2023-01-22      17:41:54
# 23630      2023-01-26        18:21:02    2023-01-26      18:53:14
# 16407      2023-01-19        14:00:37    2023-01-19      14:35:14
# 41898      2023-02-14        10:14:01    2023-02-14      10:34:12
# 21561      2023-01-24        17:06:11    2023-01-24      17:47:32
#
#       Run_End_Time_Date Run_End_Time_Time Vehicle_Number Vehicle_Type
# 19238        2023-01-22          20:00:00            602          BUS
# 23630        2023-01-26          19:00:00           1742          CAR
# 16407        2023-01-19          22:00:00           1505          BUS
# 41898        2023-02-14          19:20:00            805          BUS
# 21561        2023-01-24          23:00:00           1503          BUS
#
# [5 rows x 26 columns]

# %% [markdown]
# # *c) Lookup and reference*
# ## * i. Retrieve Origin/Destination XY coordinates (use appropriate formulas from Reference Sheet).
# ## * Correct errors where necessary, and standardize naming to be consistent where possible.
# ## * ii. Freeze rows and columns as appropriate for viewing by a business manager.

# %%
df_ref
